# %% [markdown]
# <a href="https://colab.research.google.com/github/Sreejith-CG/Machine-Learning/blob/main/Road_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("/content/RTA Dataset(1).csv")
df
# Out:
#           Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0     17:02:00      Monday              18-30          Male
# 1     17:02:00      Monday              31-50          Male
# 2     17:02:00      Monday              18-30          Male
# 3      1:06:00      Sunday              18-30          Male
# 4      1:06:00      Sunday              18-30          Male
# ...        ...         ...                ...           ...
# 2990   6:08:00     Tuesday              31-50          Male
# 2991  17:10:00      Sunday              31-50          Male
# 2992  17:10:00    Thursday            Over 51          Male
# 2993  17:10:00    Thursday            Over 51          Male
# 2994  17:16:00      Monday              31-50          Male
#
#        Educational_level Vehicle_driver_relation Driving_experience  \
# 0      Above high school                Employee              1-2yr
# 1     Junior high school                Employee         Above 10yr
# 2     Junior high school                Employee              1-2yr
# 3     Junior high school                Employee             5-10yr
# 4     Junior high school                Employee              2-5yr
# ...                  ...                     ...                ...
# 2990  Junior high school                Employee                NaN
# 2991                 NaN                Employee             5-10yr
# 2992   Writing & reading                Employee          Below 1yr
# 2993  Junior high school                Employee          Below 1yr
# 2994  Junior high school                Employee              1-2yr
#
#           Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 0              Automobile            Owner              Above 10yr  ...
# 1     Public (> 45 seats)            Owner                 5-10yrs  ...
# 2         Lorry (41?100Q)            Owner                     NaN  ...
# 3     Public (> 45 seats)     Governmental                     NaN  ...
# 4                     NaN            Owner                 5-10yrs  ...
# ...                   ...              ...                     ...  ...
# 2990      Special vehicle            Owner                   1-2yr  ...
# 2991      Lorry (41?100Q)            Owner                     NaN  ...
# 2992     Pick up upto 10Q            Owner                 5-10yrs  ...
# 2993       Lorry (11?40Q)            Owner                     NaN  ...
# 2994      Lorry (41?100Q)            Owner                     NaN  ...
#
#      Vehicle_movement   Casualty_class Sex_of_casualty Age_band_of_casualty  \
# 0      Going straight               na              na                   na
# 1      Going straight               na              na                   na
# 2      Going straight  Driver or rider            Male                31-50
# 3      Going straight       Pedestrian          Female                18-30
# 4      Going straight               na              na                   na
# ...               ...              ...             ...                  ...
# 2990              NaN        Passenger          Female              Over 51
# 2991   Going straight               na              na                   na
# 2992   Going straight               na              na                   na
# 2993   Going straight  Driver or rider          Female              Over 51
# 2994              NaN              NaN             NaN                  NaN
#
#      Casualty_severity Work_of_casuality Fitness_of_casuality  \
# 0                   na               NaN                  NaN
# 1                   na               NaN                  NaN
# 2                    3            Driver                  NaN
# 3                    3            Driver               Normal
# 4                   na               NaN                  NaN
# ...                ...               ...                  ...
# 2990                 3            Driver               Normal
# 2991                na            Driver               Normal
# 2992                na            Driver               Normal
# 2993                 3               NaN                  NaN
# 2994               NaN               NaN                  NaN
#
#      Pedestrian_movement           Cause_of_accident Accident_severity
# 0       Not a Pedestrian             Moving Backward     Slight Injury
# 1       Not a Pedestrian                  Overtaking     Slight Injury
# 2       Not a Pedestrian   Changing lane to the left    Serious Injury
# 3       Not a Pedestrian  Changing lane to the right     Slight Injury
# 4       Not a Pedestrian                  Overtaking     Slight Injury
# ...                  ...                         ...               ...
# 2990    Not a Pedestrian  Changing lane to the right     Slight Injury
# 2991    Not a Pedestrian  Changing lane to the right     Slight Injury
# 2992    Not a Pedestrian       Driving at high speed     Slight Injury
# 2993    Not a Pedestrian               No distancing     Slight Injury
# 2994                 NaN                         NaN               NaN
#
# [2995 rows x 32 columns]

# %%
df.columns
# Out:
# Index(['Time', 'Day_of_week', 'Age_band_of_driver', 'Sex_of_driver',
#        'Educational_level', 'Vehicle_driver_relation', 'Driving_experience',
#        'Type_of_vehicle', 'Owner_of_vehicle', 'Service_year_of_vehicle',
#        'Defect_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians',
#        'Road_allignment', 'Types_of_Junction', 'Road_surface_type',
#        'Road_surface_conditions', 'Light_conditions', 'Weather_conditions',
#        'Type_of_collision', 'Number_of_vehicles_involved',
#        'Number_of_casualties', 'Vehicle_movement', 'Casualty_class',
#        'Sex_of_casualty', 'Age_band_of_casualty', 'Casualty_severity',
#        'Work_of_casuality', 'Fitness_of_casuality', 'Pedestrian_movement',
#        'Cause_of_accident', 'Accident_severity'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                  2994.000000           2994.000000
# mean                      1.970942              1.441216
# std                       0.621067              0.923060
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       6.000000              6.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2995 entries, 0 to 2994
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         2995 non-null   object
#  1   Day_of_week                  2995 non-null   object
#  2   Age_band_of_driver           2995 non-null   object
#  3   Sex_of_driver                2995 non-null   object
#  4   Educational_level            2819 non-null   object
#  5   Vehicle_driver_relation      2878 non-null   object
#  6   Driving_experience           2795 non-null   object
#  7   Type_of_vehicle              2742 non-null   object
#  8   Owner_of_vehicle             2879 non-null   object
#  9   Service_year_of_vehicle      1977 non-null   object
#  10  Defect_of_vehicle            1870 non-null   object
#  11  Area_accident_occured        2934 non-null   object
#  12  Lanes_or_Medians             2890 non-null   object
#  13  Road_allignment              2958 non-null   object
#  14  Types_of_Junction            2994 non-null   object
#  15  Road_surface_type            2949 non-null   object
#  16  Road_surface_conditions      2994 non-null   object
#  17  Light_conditions             2994 non-null   object
#  18  Weather_conditions           2994 non-null   object
#  19  Type_of_collision            2969 non-null   object
#  20  Number_of_vehicles_involved  2994 non-null   float64
#  21  Number_of_casualties         2994 non-null   float64
#  22  Vehicle_movement             2957 non-null   object
#  23  Casualty_class               2994 non-null   object
#  24  Sex_of_casualty              2994 non-null   object
#  25  Age_band_of_casualty         2994 non-null   object
#  26  Casualty_severity            2994 non-null   object
#  27  Work_of_casuality            2191 non-null   object
#  28  Fitness_of_casuality         2331 non-null   object
#  29  Pedestrian_movement          2994 non-null   object
#  30  Cause_of_accident            2994 non-null   object
#  31  Accident_severity            2994 non-null   object
# dtypes: float64(2), object(30)
# memory usage: 748.9+ KB

# %%
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# 0            Owner              Above 10yr  ...   Going straight
# 1            Owner                 5-10yrs  ...   Going straight
# 2            Owner                     NaN  ...   Going straight
# 3     Governmental                     NaN  ...   Going straight
# 4            Owner                 5-10yrs  ...   Going straight
#
#     Casualty_class Sex_of_casualty Age_band_of_casualty Casualty_severity  \
# 0               na              na                   na                na
# 1               na              na                   na                na
# 2  Driver or rider            Male                31-50                 3
# 3       Pedestrian          Female                18-30                 3
# 4               na              na                   na                na
#
#   Work_of_casuality Fitness_of_casuality Pedestrian_movement  \
# 0               NaN                  NaN    Not a Pedestrian
# 1               NaN                  NaN    Not a Pedestrian
# 2            Driver                  NaN    Not a Pedestrian
# 3            Driver               Normal    Not a Pedestrian
# 4               NaN                  NaN    Not a Pedestrian
#
#             Cause_of_accident Accident_severity
# 0             Moving Backward     Slight Injury
# 1                  Overtaking     Slight Injury
# 2   Changing lane to the left    Serious Injury
# 3  Changing lane to the right     Slight Injury
# 4                  Overtaking     Slight Injury
#
# [5 rows x 32 columns]

# %%
df.shape
# Out:
# (2995, 32)

# %%
df.dtypes
# Out:
# Time                            object
# Day_of_week                     object
# Age_band_of_driver              object
# Sex_of_driver                   object
# Educational_level               object
# Vehicle_driver_relation         object
# Driving_experience              object
# Type_of_vehicle                 object
# Owner_of_vehicle                object
# Service_year_of_vehicle         object
# Defect_of_vehicle               object
# Area_accident_occured           object
# Lanes_or_Medians                object
# Road_allignment                 object
# Types_of_Junction               object
# Road_surface_type               object
# Road_surface_conditions         object
# Light_conditions                object
# Weather_conditions              object
# Type_of_collision               object
# Number_of_vehicles_involved    float64
# Number_of_casualties           float64
# Vehicle_movement                object
# Casualty_class                  object
# Sex_of_casualty                 object
# Age_band_of_casualty            object
# Casualty_severity               object
# Work_of_casuality               object
# Fitness_of_casuality            object
# Pedestrian_movement             object
# Cause_of_accident               object
# Accident_severity               object
# dtype: object

# %%
df.isna().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               176
# Vehicle_driver_relation         117
# Driving_experience              200
# Type_of_vehicle                 253
# Owner_of_vehicle                116
# Service_year_of_vehicle        1018
# Defect_of_vehicle              1125
# Area_accident_occured            61
# Lanes_or_Medians                105
# Road_allignment                  37
# Types_of_Junction                 1
# Road_surface_type                46
# Road_surface_conditions           1
# Light_conditions                  1
# Weather_conditions                1
# Type_of_collision                26
# Number_of_vehicles_involved       1
# Number_of_casualties              1
# Vehicle_movement                 38
# Casualty_class                    1
# Sex_of_casualty                   1
# Age_band_of_casualty              1
# Casualty_severity                 1
# Work_of_casuality               804
# Fitness_of_casuality            664
# Pedestrian_movement               1
# Cause_of_accident                 1
# Accident_severity                 1
# dtype: int64

# %%
df['Time']=pd.to_datetime(df['Time'])

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2990    False
# 2991    False
# 2992    False
# 2993    False
# 2994    False
# Length: 2995, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.groupby('Accident_severity').size()
# Out:
# Accident_severity
# Fatal injury        26
# Serious Injury     375
# Slight Injury     2593
# dtype: int64

# %%
df.hist(layout=(1,6),figsize=(70,10))
plt.show()

# %%
df['Number_of_casualties'].value_counts()
# Out:
# 1.0    2225
# 2.0     448
# 3.0     181
# 4.0      81
# 6.0      32
# 5.0      27
# Name: Number_of_casualties, dtype: int64

# %%
plt.figure(figsize=(10,7))
sns.boxplot(data=df,y='Number_of_vehicles_involved',x='Number_of_casualties')
plt.show()

# %%
sns.boxplot(data=df,y='Number_of_casualties')
plt.show()

# %%
sns.boxplot(data=df,y='Number_of_vehicles_involved')
plt.show()

# %%
df['Number_of_vehicles_involved']
# Out:
# 0       2.0
# 1       2.0
# 2       2.0
# 3       2.0
# 4       2.0
#        ...
# 2990    2.0
# 2991    1.0
# 2992    2.0
# 2993    2.0
# 2994    NaN
# Name: Number_of_vehicles_involved, Length: 2995, dtype: float64

# %%
sns.scatterplot(x=df['Number_of_vehicles_involved'],y=df['Number_of_casualties'])
plt.show()

# %%
sns.pairplot(df[['Number_of_vehicles_involved','Number_of_casualties']])
plt.show()

# %%
correlation_matrix=df[['Number_of_vehicles_involved','Number_of_casualties']].corr()
sns.heatmap(correlation_matrix,annot=True)
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.pie(x=df['Accident_severity'].value_counts().values,
        labels=df['Accident_severity'].value_counts().index,autopct='%2.2f%%')
plt.show()

# %%
grid=sns.FacetGrid(data=df,col='Accident_severity',height=4,aspect=1,sharey=False)

grid.map(sns.countplot,'Number_of_vehicles_involved',palette=['black','green','brown'])
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/axisgrid.py:670: UserWarning: Using the countplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
lists=['Vehicle_driver_relation', 'Work_of_casuality', 'Fitness_of_casuality','Day_of_week','Casualty_severity','Time','Sex_of_driver','Educational_level','Defect_of_vehicle','Owner_of_vehicle','Service_year_of_vehicle', 'Road_surface_type','Sex_of_casualty']
df.drop(columns = lists, inplace=True)
df.shape
# Out:
# (2995, 19)

# %%
fill_cols = ['Driving_experience','Type_of_vehicle','Area_accident_occured','Lanes_or_Medians','Road_allignment','Types_of_Junction','Type_of_collision','Vehicle_movement']
for i in fill_cols:
    mode = df[i].mode()[0]
    df[i].fillna(mode, inplace=True)

df.isna().sum()
# Out:
# Age_band_of_driver             0
# Driving_experience             0
# Type_of_vehicle                0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Age_band_of_casualty           0
# Pedestrian_movement            0
# Cause_of_accident              0
# Accident_severity              0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

LE=LabelEncoder()
df=df.apply(LE.fit_transform)
df
# Out:
#       Age_band_of_driver  Driving_experience  Type_of_vehicle  \
# 0                      0                   0                0
# 1                      1                   3               11
# 2                      0                   0                5
# 3                      0                   2               11
# 4                      0                   1                0
# ...                  ...                 ...              ...
# 2990                   1                   2               13
# 2991                   1                   2                5
# 2992                   2                   4                8
# 2993                   2                   4                4
# 2994                   1                   0                5
#
#       Area_accident_occured  Lanes_or_Medians  Road_allignment  \
# 0                         9                 2                5
# 1                         6                 4                5
# 2                         1                 6                5
# 3                         6                 6                6
# 4                         4                 6                5
# ...                     ...               ...              ...
# 2990                      6                 2                6
# 2991                      6                 2                6
# 2992                      6                 2                5
# 2993                      7                 2                5
# 2994                      7                 2                5
#
#       Types_of_Junction  Road_surface_conditions  Light_conditions  \
# 0                     1                        0                 3
# 1                     1                        0                 3
# 2                     1                        0                 3
# 3                     6                        0                 0
# 4                     6                        0                 0
# ...                 ...                      ...               ...
# 2990                  6                        0                 3
# 2991                  1                        0                 3
# 2992                  0                        0                 3
# 2993                  0                        0                 3
# 2994                  6                        3                 4
#
#       Weather_conditions  Type_of_collision  Number_of_vehicles_involved  \
# 0                      2                  3                            1
# 1                      2                  8                            1
# 2                      2                  2                            1
# 3                      2                  8                            1
# 4                      2                  8                            1
# ...                  ...                ...                          ...
# 2990                   2                  1                            1
# 2991                   2                  8                            0
# 2992                   2                  1                            1
# 2993                   2                  8                            1
# 2994                   9                  8                            5
#
#       Number_of_casualties  Vehicle_movement  Casualty_class  \
# 0                        1                 2               3
# 1                        1                 2               3
# 2                        1                 2               0
# 3                        1                 2               2
# 4                        1                 2               3
# ...                    ...               ...             ...
# 2990                     0                 2               1
# 2991                     0                 2               3
# 2992                     0                 2               3
# 2993                     0                 2               0
# 2994                     6                 2               4
#
#       Age_band_of_casualty  Pedestrian_movement  Cause_of_accident  \
# 0                        4                    5                  9
# 1                        4                    5                 16
# 2                        1                    5                  0
# 3                        0                    5                  1
# 4                        4                    5                 16
# ...                    ...                  ...                ...
# 2990                     2                    5                  1
# 2991                     4                    5                  1
# 2992                     4                    5                  2
# 2993                     2                    5                 10
# 2994                     5                    9                 20
#
#       Accident_severity
# 0                     2
# 1                     2
# 2                     1
# 3                     2
# 4                     2
# ...                 ...
# 2990                  2
# 2991                  2
# 2992                  2
# 2993                  2
# 2994                  3
#
# [2995 rows x 19 columns]

# %%
plt.figure(figsize=[20,15])
sns.heatmap(df.corr(),annot=True)

# %%
x=df.drop(columns=["Accident_severity"])
y=df["Accident_severity"]
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier()
params={"n_estimators" : [100,200],
        "criterion" : ["gini","entropy"]}

# %%
model=RandomForestClassifier(criterion="entropy",n_estimators=200)
model.fit(xtrain,ytrain)
ypred=model.predict(xtest)

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
print(accuracy_score(ytest,ypred))
print(classification_report(ytest,ypred))
cm=confusion_matrix(ytest,ypred)
sns.heatmap(cm,annot=True)
# Out:
# 0.8654060066740823
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         9
#            1       1.00      0.01      0.02       112
#            2       0.87      1.00      0.93       777
#            3       0.00      0.00      0.00         1
#
#     accuracy                           0.87       899
#    macro avg       0.47      0.25      0.24       899
# weighted avg       0.87      0.87      0.80       899
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
